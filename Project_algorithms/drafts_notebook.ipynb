# %%
import pandas as pd

# %%
len(instances)
# Out:
# 20

# %%
mil_results=[7328.2,7262.2,7012.77,10661,1376.8,14250.2,10062.9,9757.38,16151.1,22182.3,15605.1,14869.6,18963.9,7462.35,12992,11793.7,21493.6,17004.6,11529.1,13157.3]
greedy_results=[11582.65,13913.35,16397.01,19371.32,21539.81,22982.34,21693.41,19309.61,22254.55,28798.81,24210.07,24045.61,34123.11,19786.24,25998.36,29972.23,34546.98,36827.12,36656.98,37229.92]
grasp_results=[11575.57,11028.25,15244.82,17874.48,20312.92,20062.40,20544.799,19038.67,21498.25,28773.14,24041.72,23059.18,32086.80,17946.55,25815.20,29166.50,34325.23,36408,34442.86,36066.78]

# %%
df =pd.DataFrame({"MILP":mil_results, "Greedy":greedy_results, "GRASP":grasp_results})

# %%
import matplotlib.pyplot as plt
instances = [x for x in range(0,20)]
len(instances)
plt.plot(instances, mil_results, color="blue", label="MILP")
plt.plot(instances, greedy_results, color="red", label="Greedy")
plt.plot(instances, grasp_results, color="green", label="Grasp")
plt.xlabel("Instances")
plt.ylabel("Cost of solution")
plt.legend()
fig = plt.figure()
fig.savefig("grafic_cost.jpg")
